# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import os
import random
import numpy as np
import matplotlib.pyplot as plt

# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
gpu_device = tf.config.experimental.list_physical_devices('GPU')
print(f"Number of GPU = {len(gpu_device)}")
#tf.config.experimental.set_memory_growth(gpu_device[0], True)
# Out:
# Number of GPU = 0

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %%
digit = 9 # Change to choose new digit
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %%
x_train = x_train.reshape(-1, 28*28).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28*28).astype("float32") / 255.0

# %%
digit = 9 # Change to choose new digit
a = x_train[digit].reshape(28,28)
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
model = keras.Sequential([
    keras.Input(shape=28*28),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.1460 - val_accuracy: 0.9753
# Epoch 2/20
# 657/657 [==============================] - 6s 8ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.1473 - val_accuracy: 0.9754
# Epoch 3/20
# 657/657 [==============================] - 4s 7ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.1503 - val_accuracy: 0.9764
# Epoch 4/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1580 - val_accuracy: 0.9768
# Epoch 5/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1545 - val_accuracy: 0.9773
# Epoch 6/20
# 657/657 [==============================] - 5s 7ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1585 - val_accuracy: 0.9771
# Epoch 7/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1565 - val_accuracy: 0.9776
# Epoch 8/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1563 - val_accuracy: 0.9783
# Epoch 9/20
# 657/657 [==============================] - 6s 8ms/step - loss: 1.6780e-04 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9781
# Epoch 10/20
# 657/657 [==============================] - 5s 8ms/step - loss: 1.5070e-04 - accuracy: 0.9999 - val_loss: 0.1543 - val_accuracy: 0.9788
# Epoch 11/20
# 657/657 [==============================] - 6s 9ms/step - loss: 2.4915e-05 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9784
# Epoch 12/20
# 657/657 [==============================] - 5s 8ms/step - loss: 1.0605e-05 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.9787
# Epoch 13/20
# 657/657 [==============================] - 6s 8ms/step - loss: 8.0928e-06 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9788
# Epoch 14/20
# 657/657 [==============================] - 6s 9ms/step - loss: 6.9268e-06 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9787
# Epoch 15/20
# 657/657 [==============================] - 5s 8ms/step - loss: 6.4007e-06 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9789
# Epoch 16/20
# 657/657 [==============================] - 6s 10ms/step - loss: 5.8407e-06 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9789
# Epoch 17/20
# 657/657 [==============================] - 5s 8ms/step - loss: 5.4222e-06 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9788
# Epoch 18/20
# 657/657 [==============================] - 6s 9ms/step - loss: 5.0999e-06 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9789
# Epoch 19/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.7915e-06 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.9790
# Epoch 20/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.5337e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h1 = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.2719e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 2/20
# 657/657 [==============================] - 4s 7ms/step - loss: 4.2708e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 3/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.2698e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 4/20
# 657/657 [==============================] - 4s 7ms/step - loss: 4.2686e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 5/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.2675e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 6/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.2664e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 7/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.2654e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 8/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.2644e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 9/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.2633e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 10/20
# 657/657 [==============================] - 4s 7ms/step - loss: 4.2623e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 11/20
# 657/657 [==============================] - 6s 9ms/step - loss: 4.2613e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 12/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.2604e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 13/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.2594e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 14/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.2584e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 15/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.2574e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 16/20
# 657/657 [==============================] - 4s 7ms/step - loss: 4.2564e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 17/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.2555e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 18/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.2545e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 19/20
# 657/657 [==============================] - 4s 5ms/step - loss: 4.2535e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788
# Epoch 20/20
# 657/657 [==============================] - 6s 8ms/step - loss: 4.2525e-06 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9788

# %%
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=0.001), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h2 = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 5s 7ms/step - loss: 4.1163e-06 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9789
# Epoch 2/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.9990e-06 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9788
# Epoch 3/20
# 657/657 [==============================] - 6s 8ms/step - loss: 3.7945e-06 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9788
# Epoch 4/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.6629e-06 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9788
# Epoch 5/20
# 657/657 [==============================] - 6s 10ms/step - loss: 3.5276e-06 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9787
# Epoch 6/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.4014e-06 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9787
# Epoch 7/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.2890e-06 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9786
# Epoch 8/20
# 657/657 [==============================] - 6s 9ms/step - loss: 3.1888e-06 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9787
# Epoch 9/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.0881e-06 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9788
# Epoch 10/20
# 657/657 [==============================] - 6s 10ms/step - loss: 3.0070e-06 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9790
# Epoch 11/20
# 657/657 [==============================] - 5s 7ms/step - loss: 2.9157e-06 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9789
# Epoch 12/20
# 657/657 [==============================] - 6s 8ms/step - loss: 2.8444e-06 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9790
# Epoch 13/20
# 657/657 [==============================] - 5s 8ms/step - loss: 2.7580e-06 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9789
# Epoch 14/20
# 657/657 [==============================] - 5s 8ms/step - loss: 2.7005e-06 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9789
# Epoch 15/20
# 657/657 [==============================] - 6s 10ms/step - loss: 2.6240e-06 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9788
# Epoch 16/20
# 657/657 [==============================] - 4s 7ms/step - loss: 2.5636e-06 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9789
# Epoch 17/20
# 657/657 [==============================] - 6s 10ms/step - loss: 2.5107e-06 - accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9789
# Epoch 18/20
# 657/657 [==============================] - 5s 8ms/step - loss: 2.4518e-06 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9790
# Epoch 19/20
# 657/657 [==============================] - 6s 10ms/step - loss: 2.3945e-06 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9788
# Epoch 20/20
# 657/657 [==============================] - 4s 7ms/step - loss: 2.3429e-06 - accuracy: 1.0000 - val_loss: 0.1705 - val_accuracy: 0.9788

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='adam train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'adam optimizer validation accuracy')

plt.plot(h1.history['accuracy'], 'o-', label='SGD optimizer train accuracy')
plt.plot(h1.history['val_accuracy'], 'o-', label = 'SGD optimizer validation accuracy')

plt.plot(h2.history['accuracy'], 'o-', label='RMSprop optimizer train accuracy')
plt.plot(h2.history['val_accuracy'], 'o-', label = 'RMSprop optimizer validation accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='adam train loss')
plt.plot(h.history['val_loss'], 'o-', label='adam validation loss')

plt.plot(h1.history['loss'], 'o-', label='SGD train loss')
plt.plot(h1.history['val_loss'], 'o-', label='SGD validation loss')

plt.plot(h2.history['loss'], 'o-', label='RMSprop train loss')
plt.plot(h2.history['val_loss'], 'o-', label='RMSprop validation loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1284 - accuracy: 0.9810
#
# Test accuracy: 0.9810000061988831

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
ROWS = 5
COLS = 20

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model.predict(sample_images)

i = 0

plt.figure(figsize=(20,5))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i]) 
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1
        
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
def test(i):
    img = x_test[i]
    predictions = model.predict([img.reshape(-1,784)])

    plt.figure()
    plt.imshow(img.reshape(28,28), cmap='gray_r')
    plt.xticks([])
    plt.yticks([])

    plt.ylabel(f"True Label: {y_test[i]}", color='g') # ground truth

    prediction = np.argmax(predictions) 
    confidence = predictions[0][prediction]

    if y_test[i] == prediction:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='b')
    else:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='r')
    plt.show()

# %%
test(8)
# Out:
# 1/1 [==============================] - 0s 74ms/step

# %%
test(4500)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
test(76)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
test(2156)
# Out:
# 1/1 [==============================] - 0s 27ms/step
